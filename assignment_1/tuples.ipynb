# %% [markdown]
# ## Part 2 - Tuples

# %% [markdown]
# #### Group 10
# *Estefanny Mejía <br>
# *Luz Supo <br>
# *Nicolas Silva <br>
# *Marco Virú <br>

# %% [markdown]
# Create the following tuple:

# %%
ages = (20, 25, 22, 30, 28)

# %% [markdown]
# 1. Print the tuple

# %%
print(ages)
# Out:
# (20, 25, 22, 30, 28)

# %% [markdown]
# 2. Display the first and the last elements

# %%
#Primer elemento: se usa [0] para que nos muestre el primer elemento.
ages[0]
# Out:
# 20

# %%
#Último elemento: se usa [-1] para que nos muestre el último elemento.
ages[-1]
# Out:
# 28

# %% [markdown]
# 3. Display:<br>
#     *The maximum value <br>
#     *The minimum value <br>
#     *The number of elements <br>

# %%
#Máximo valor
print (max(ages))
# Out:
# 30

# %%
#Mínimo valor
print (min(ages))
# Out:
# 20

# %%
#Número de elementos
print (len(ages))
# Out:
# 5

# %% [markdown]
# 4. Try to modify one of the elements of the tuple.

# %%
print (ages)
# Out:
# (20, 25, 22, 30, 28)

# %%
ages[1] = "18"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 ages[1] = "18"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 5. Write a brief comment in the script explaining why Python does not allow this modification.

# %% [markdown]
# Cuando se trata de tuple, no se puede modificar porque en Python las tuplas son inmutables. Esto significa que, una vez creadas, no se pueden agregar, cambiar o eliminar los elementos que contienen.
